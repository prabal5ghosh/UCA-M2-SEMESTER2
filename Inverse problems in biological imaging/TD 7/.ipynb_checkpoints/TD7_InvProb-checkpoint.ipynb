# %% [markdown]
# # Tutorial \#7 (23 Feb. 2024)
#
# Faisal Jayousi
#
# jayousi@unice.fr

# %% [markdown]
# ## What is DeepInverse all about?
# DeepInverse is a Pytorch based Python module for solving imaging inverse problems with Deep Learning. If provides a range of linear and non-linear forward operators, such as blurring, denoising and downsampling.
#
# ## Importing DeepInverse
# * You need to install the DeepInverse module for this tutorial: ```pip install deepinv```
# * To import it: use ```import deepinv```
# * Documentation: https://deepinv.github.io/deepinv/index.html

# %%
# !pip install deepinv
# Out:
# Collecting deepinv
#   Downloading deepinv-0.2.2-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: numpy in c:\users\praba\anaconda3\lib\site-packages (from deepinv) (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\praba\anaconda3\lib\site-packages (from deepinv) (3.7.2)
# Collecting hdf5storage (from deepinv)
#   Downloading hdf5storage-0.1.19-py2.py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: tqdm in c:\users\praba\anaconda3\lib\site-packages (from deepinv) (4.65.0)
# Requirement already satisfied: torch in c:\users\praba\anaconda3\lib\site-packages (from deepinv) (2.2.0)
# Requirement already satisfied: torchvision in c:\users\praba\anaconda3\lib\site-packages (from deepinv) (0.17.0)
# Collecting torchmetrics (from deepinv)
#   Downloading torchmetrics-1.6.1-py3-none-any.whl.metadata (21 kB)
# Collecting einops (from deepinv)
#   Downloading einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting wandb (from deepinv)
#   Downloading wandb-0.19.7-py3-none-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: scipy in c:\users\praba\anaconda3\lib\site-packages (from deepinv) (1.11.1)
# Requirement already satisfied: h5py>=2.1 in c:\users\praba\anaconda3\lib\site-packages (from hdf5storage->deepinv) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\praba\anaconda3\lib\site-packages (from matplotlib->deepinv) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\praba\anaconda3\lib\site-packages (from matplotlib->deepinv) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\praba\anaconda3\lib\site-packages (from matplotlib->deepinv) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\praba\anaconda3\lib\site-packages (from matplotlib->deepinv) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\praba\anaconda3\lib\site-packages (from matplotlib->deepinv) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\praba\anaconda3\lib\site-packages (from matplotlib->deepinv) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\praba\anaconda3\lib\site-packages (from matplotlib->deepinv) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\praba\anaconda3\lib\site-packages (from matplotlib->deepinv) (2.8.2)
# Requirement already satisfied: filelock in c:\users\praba\anaconda3\lib\site-packages (from torch->deepinv) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\praba\anaconda3\lib\site-packages (from torch->deepinv) (4.9.0)
# Requirement already satisfied: sympy in c:\users\praba\anaconda3\lib\site-packages (from torch->deepinv) (1.11.1)
# Requirement already satisfied: networkx in c:\users\praba\anaconda3\lib\site-packages (from torch->deepinv) (3.1)
# Requirement already satisfied: jinja2 in c:\users\praba\anaconda3\lib\site-packages (from torch->deepinv) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\praba\anaconda3\lib\site-packages (from torch->deepinv) (2023.4.0)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics->deepinv)
#   Downloading lightning_utilities-0.12.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: requests in c:\users\praba\anaconda3\lib\site-packages (from torchvision->deepinv) (2.31.0)
# Requirement already satisfied: colorama in c:\users\praba\anaconda3\lib\site-packages (from tqdm->deepinv) (0.4.6)
# Requirement already satisfied: click!=8.0.0,>=7.1 in c:\users\praba\anaconda3\lib\site-packages (from wandb->deepinv) (8.0.4)
# Collecting docker-pycreds>=0.4.0 (from wandb->deepinv)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb->deepinv)
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in c:\users\praba\anaconda3\lib\site-packages (from wandb->deepinv) (3.10.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in c:\users\praba\anaconda3\lib\site-packages (from wandb->deepinv) (4.23.4)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\praba\anaconda3\lib\site-packages (from wandb->deepinv) (5.9.0)
# Collecting pydantic<3,>=2.6 (from wandb->deepinv)
#   Downloading pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: pyyaml in c:\users\praba\anaconda3\lib\site-packages (from wandb->deepinv) (6.0)
# Collecting sentry-sdk>=2.0.0 (from wandb->deepinv)
#   Downloading sentry_sdk-2.22.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting setproctitle (from wandb->deepinv)
#   Downloading setproctitle-1.3.5-cp311-cp311-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: setuptools in c:\users\praba\anaconda3\lib\site-packages (from wandb->deepinv) (68.0.0)
# Requirement already satisfied: six>=1.4.0 in c:\users\praba\anaconda3\lib\site-packages (from docker-pycreds>=0.4.0->wandb->deepinv) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb->deepinv)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=2.6->wandb->deepinv)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic<3,>=2.6->wandb->deepinv)
#   Downloading pydantic_core-2.27.2-cp311-cp311-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-extensions>=4.8.0 (from torch->deepinv)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\praba\anaconda3\lib\site-packages (from requests->torchvision->deepinv) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\praba\anaconda3\lib\site-packages (from requests->torchvision->deepinv) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\praba\anaconda3\lib\site-packages (from requests->torchvision->deepinv) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\praba\anaconda3\lib\site-packages (from requests->torchvision->deepinv) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\praba\anaconda3\lib\site-packages (from jinja2->torch->deepinv) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\praba\anaconda3\lib\site-packages (from sympy->torch->deepinv) (1.3.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->deepinv)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Downloading deepinv-0.2.2-py3-none-any.whl (516 kB)
#    ---------------------------------------- 0.0/516.8 kB ? eta -:--:--
#    --------------- ------------------------ 194.6/516.8 kB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 516.8/516.8 kB 6.5 MB/s eta 0:00:00
# Downloading einops-0.8.1-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.4 kB ? eta -:--:--
#    ---------------------------------------- 64.4/64.4 kB ? eta 0:00:00
# Downloading hdf5storage-0.1.19-py2.py3-none-any.whl (53 kB)
#    ---------------------------------------- 0.0/53.6 kB ? eta -:--:--
#    ---------------------------------------- 53.6/53.6 kB 2.7 MB/s eta 0:00:00
# Downloading torchmetrics-1.6.1-py3-none-any.whl (927 kB)
#    ---------------------------------------- 0.0/927.3 kB ? eta -:--:--
#    ------------------------------- ------- 757.8/927.3 kB 24.1 MB/s eta 0:00:01
#    --------------------------------------- 927.3/927.3 kB 14.8 MB/s eta 0:00:00
# Downloading wandb-0.19.7-py3-none-win_amd64.whl (20.3 MB)
#    ---------------------------------------- 0.0/20.3 MB ? eta -:--:--
#    -- ------------------------------------- 1.1/20.3 MB 34.4 MB/s eta 0:00:01
#    --- ------------------------------------ 1.8/20.3 MB 19.3 MB/s eta 0:00:01
#    ---- ----------------------------------- 2.4/20.3 MB 22.2 MB/s eta 0:00:01
#    ------ --------------------------------- 3.5/20.3 MB 18.7 MB/s eta 0:00:01
#    -------- ------------------------------- 4.2/20.3 MB 16.8 MB/s eta 0:00:01
#    ---------- ----------------------------- 5.4/20.3 MB 19.1 MB/s eta 0:00:01
#    ------------- -------------------------- 6.6/20.3 MB 19.3 MB/s eta 0:00:01
#    -------------- ------------------------- 7.2/20.3 MB 18.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 8.3/20.3 MB 19.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 8.8/20.3 MB 18.1 MB/s eta 0:00:01
#    ------------------- -------------------- 9.9/20.3 MB 18.7 MB/s eta 0:00:01
#    --------------------- ------------------ 10.7/20.3 MB 18.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 12.0/20.3 MB 19.2 MB/s eta 0:00:01
#    ------------------------ --------------- 12.5/20.3 MB 19.3 MB/s eta 0:00:01
#    -------------------------- ------------- 13.4/20.3 MB 19.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 14.4/20.3 MB 20.5 MB/s eta 0:00:01
#    ------------------------------ --------- 15.5/20.3 MB 19.8 MB/s eta 0:00:01
#    -------------------------------- ------- 16.5/20.3 MB 21.1 MB/s eta 0:00:01
#    --------------------------------- ------ 17.2/20.3 MB 20.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 18.1/20.3 MB 20.5 MB/s eta 0:00:01
#    -------------------------------------- - 19.3/20.3 MB 22.6 MB/s eta 0:00:01
#    ---------------------------------------  19.8/20.3 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  20.2/20.3 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  20.2/20.3 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  20.2/20.3 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  20.2/20.3 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  20.2/20.3 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  20.2/20.3 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  20.2/20.3 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  20.2/20.3 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  20.2/20.3 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  20.2/20.3 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  20.2/20.3 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  20.2/20.3 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  20.2/20.3 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------- 20.3/20.3 MB 9.6 MB/s eta 0:00:00
# Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
#    ---------------------------------------- 0.0/207.6 kB ? eta -:--:--
#    --------------------------------------- 207.6/207.6 kB 13.2 MB/s eta 0:00:00
# Downloading lightning_utilities-0.12.0-py3-none-any.whl (28 kB)
# Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
#    ---------------------------------------- 0.0/431.7 kB ? eta -:--:--
#    --------------------------------------- 431.7/431.7 kB 28.1 MB/s eta 0:00:00
# Downloading pydantic_core-2.27.2-cp311-cp311-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----------------- ---------------------- 0.9/2.0 MB 18.1 MB/s eta 0:00:01
#    ------------------------------- -------- 1.6/2.0 MB 16.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 15.8 MB/s eta 0:00:00
# Downloading sentry_sdk-2.22.0-py2.py3-none-any.whl (325 kB)
#    ---------------------------------------- 0.0/325.8 kB ? eta -:--:--
#    --------------------------------------- 325.8/325.8 kB 10.2 MB/s eta 0:00:00
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading setproctitle-1.3.5-cp311-cp311-win_amd64.whl (12 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.8 kB ? eta -:--:--
#    ---------------------------------------  61.4/62.8 kB ? eta -:--:--
#    ---------------------------------------  61.4/62.8 kB ? eta -:--:--
#    ---------------------------------------  61.4/62.8 kB ? eta -:--:--
#    ---------------------------------------- 62.8/62.8 kB 420.4 kB/s eta 0:00:00
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: typing-extensions, smmap, setproctitle, sentry-sdk, einops, docker-pycreds, annotated-types, pydantic-core, lightning-utilities, hdf5storage, gitdb, torchmetrics, pydantic, gitpython, wandb, deepinv
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.9.0
#     Uninstalling typing_extensions-4.9.0:
#       Successfully uninstalled typing_extensions-4.9.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.8
#     Uninstalling pydantic-1.10.8:
#       Successfully uninstalled pydantic-1.10.8
# Successfully installed annotated-types-0.7.0 deepinv-0.2.2 docker-pycreds-0.4.0 einops-0.8.1 gitdb-4.0.12 gitpython-3.1.44 hdf5storage-0.1.19 lightning-utilities-0.12.0 pydantic-2.10.6 pydantic-core-2.27.2 sentry-sdk-2.22.0 setproctitle-1.3.5 smmap-5.0.2 torchmetrics-1.6.1 typing-extensions-4.12.2 wandb-0.19.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-nightly-intel 2.17.0.dev20240229 requires keras-nightly~=3.1.0.dev, which is not installed.
# tf-nightly-intel 2.17.0.dev20240229 requires ml-dtypes~=0.3.1, but you have ml-dtypes 0.5.1 which is incompatible.
# anaconda-cloud-auth 0.1.3 requires pydantic<2.0, but you have pydantic 2.10.6 which is incompatible.
# langchain 0.0.225 requires pydantic<2,>=1, but you have pydantic 2.10.6 which is incompatible.
# langchainplus-sdk 0.0.20 requires pydantic<2,>=1, but you have pydantic 2.10.6 which is incompatible.
# tensorflow-intel 2.15.0 requires ml-dtypes~=0.2.0, but you have ml-dtypes 0.5.1 which is incompatible.
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import deepinv as dinv
import matplotlib.pyplot as plt
import torch

import numpy as np
import random

# %% [markdown]
# ## LISTA
#
# The subject of this tutorial is LISTA (Learned Iterative Soft-Thresholding Algorithm). The main difference with the classical ISTA algorithm is that the thresholding parameters of the proximal operator are learned. For a use-case in compressed sensing, see https://deepinv.github.io/deepinv/auto_examples/unfolded/demo_LISTA.html.
#
# **NB**: Using a GPU for this tutorial is recommended. However, the parameters have been modestly adjusted to ensure efficient execution on a CPU in minimal time.
#
# The steps are as follows:
# 1. Data generation: as a first approach, we will use the well-known MNIST dataset. It can be downloaded using ```datasets.MNIST()```. See the documentation for more details on the arguments.
# 2. Generate blurred images: you can use ```dinv.datasets.generate_dataset()```. An appropriate blurring model needs to be defined first. For simplicity, choose a gaussian kernel with $\sigma=3$.
# 3. Load the data using PyTorch's dataloaders. Don't forget to shuffle the training data. You may use DeepInverse's ```datasets.HDF5Dataset()```.
# 4. Train using the training data. See DeepInverse's ```training_utils```.
# 5. Test your model on the test dataset. Plot the learned stepsize and regularisastion parameter.
# 6. Test your model on a generated SMLM image. How well does it work?
# 7. Redo everything but with generated SMLM images (use ~250 images for training).
#
#
# ### Data generation

# %%
# Function to generate an SMLM image
def generate_ground_truth(n: int, n_mol: int, margin: int) -> np.ndarray:
    """
    n: shape of output
    n_mol: number of molecules
    margin: to avoid placing molecules near the edges
    """
    gt = np.zeros((n, n), dtype=np.double)
    for _ in np.arange(n_mol):
        i = random.randint(margin, n-margin)
        j = random.randint(margin, n-margin)
        gt[i, j] = 255.
    return gt

# %%
# Reproducibility
torch.manual_seed(0)
random.seed(234)

device = dinv.utils.get_freer_gpu() if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
img_size = 28
n_channels = 1
operation = "blur"
train_dataset_name = "MNIST_train"

# Download MNIST dataset in HDF5 folders and load them.
# train_test_transform = ...
# train_base_dataset = ...
# test_base_dataset = ...

import deepinv as dinv
from torchvision import datasets, transforms

# save_dir = dinv.utils.demo.get_data_home() / 'MNIST'

save_dir = dinv.utils.demo.get_data_home() / 'MNIST'

train_test_transform = transforms.Compose([transforms.ToTensor()])
train_base_dataset = datasets.MNIST(root=save_dir, train=True,
                            transform=train_test_transform, download=True)
test_base_dataset = datasets.MNIST(root=save_dir, train=False, transform=train_test_transform)

# %%
num_workers = 0

# # Generate the forward operator
# physics = ...
physics = dinv.physics.Blur(filter = dinv.physics.blur.gaussian_blur(sigma=(1, 1), angle=0), device = device, img_shape = (1,28,28),fast = True)


my_dataset_name = "demo_LISTA"
n_images_max = 200  # number of images used for training

# generated_datasets_path = ...
# measurement_dir = DATA_DIR / train_dataset_name / operation
measurement_dir = "C:/sers/praba/Documents/GitHub/UCA-M2-SEMESTER2/Inverse problems in biological imaging/TD 7"
generated_datasets_path = dinv.datasets.generate_dataset(
    train_dataset=train_base_dataset,
    test_dataset=test_base_dataset,
    physics=physics,
    device=device,
    save_dir=measurement_dir,
    train_datapoints=n_images_max,
    test_datapoints=8,
    num_workers=num_workers,
    dataset_filename=str(my_dataset_name),
)
# # Load datasets
# train_dataset = ...
# test_dataset = ...


train_dataset = dinv.datasets.HDF5Dataset(path=generated_datasets_path, train=True)
test_dataset = dinv.datasets.HDF5Dataset(path=generated_datasets_path, train=False)
# Out:
# C:\Users\praba\anaconda3\Lib\site-packages\deepinv\datasets\datagenerator.py:214: UserWarning: Dataset C:/sers/praba/Documents/GitHub/UCA-M2-SEMESTER2/Inverse problems in biological imaging/TD 7/demo_LISTA0.h5 already exists, this will overwrite the previous dataset.
#   warn(
# Dataset has been saved at C:/sers/praba/Documents/GitHub/UCA-M2-SEMESTER2/Inverse problems in biological imaging/TD 7/demo_LISTA0.h5

# %% [markdown]
# ### Define algorithm

# %% [markdown]
# Same as in the previous tutorials, we will solve the following problem $$\min_x \frac{1}{2}\|Ax-y\|_2^2 + \lambda\|x\|_1$$
#
# In this tutorial, we will focus exclusively on $\ell^1$ regularisation. However, the module provides a wide range of intriguing priors, both classical and learnable. For further details, refer to https://deepinv.github.io/deepinv/deepinv.models.html. Additionally, we will optimise the selection of $\lambda$.

# %%
max_iter = 10

# data_fidelity = ...
data_fidelity = dinv.optim.L2(sigma=1.0)

# prior = ...
prior = dinv.optim.Prior(deepinv.optim.L1() for _ in range(max_iter))
# initialisation
# lamb = ...
# stepsize = ...


lamb = [1 for a in range(max_iter)]


stepsize = [torch.ones(1, device=device)] * max_iter  # initialization of the stepsizes.

sigma_denoiser_init = 0.05
# sigma_denoiser = ...
sigma_denoiser = [
    torch.ones(1, 1, device=device)
    * sigma_denoiser_init  
] * max_iter 



# params_algo = {}
params_algo = {"stepsize": stepsize,"lambda": lamb }


trainable_params = ["stepsize",
    "lambda"]

# model = ...

model = dinv.unfolded.unfolded_builder(
    iteration="PGD",
    params_algo=params_algo.copy(),
    trainable_params=trainable_params,
    data_fidelity=data_fidelity,
    max_iter=max_iter,
    prior=prior,
).to(device)

# %%
# Training parameters
epochs = 4
learning_rate = 1e-3


# Choose optimizer
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# Choose supervised training loss
losses = [dinv.loss.SupLoss(metric=dinv.metric.MSE())]

# Logging parameters
verbose = True
wandb_vis = False  # plot curves and images in Weight&Bias

# Batch sizes and data loaders
train_batch_size = 1
test_batch_size = 8

# train_dataloader = ...
# test_dataloader = ...

train_dataloader = torch.utils.data.DataLoader( train_dataset, batch_size= train_batch_size, num_workers=0, shuffle=True)
test_dataloader =  torch.utils.data.DataLoader( test_dataset, batch_size= test_batch_size, num_workers=0, shuffle=False)

# %%
CKPT_DIR = "C:/Users/praba/Documents/GitHub/UCA-M2-SEMESTER2/Inverse problems in biological imaging/TD 7/datasets"

# %%
# Train model
...
from pathlib import Path
BASE_DIR = Path("C:/Users/praba/Documents/GitHub/UCA-M2-SEMESTER2/Inverse problems in biological imaging/TD 7/datasets")
DATA_DIR = BASE_DIR / "measurements"
RESULTS_DIR = BASE_DIR / "results"
CKPT_DIR = BASE_DIR / "ckpts"

trainer = dinv.Trainer(
    model,
    physics=physics,
    train_dataloader=train_dataloader,
    eval_dataloader=test_dataloader,
    epochs=epochs,
    losses=losses,
    optimizer=optimizer,
    device=device,
#     save_path=str(CKPT_DIR / operation),
    verbose=verbose)

# %%
model = trainer.train()
# Out:
# The model has 20 trainable parameters
# Train epoch 1/4:   0%|                                                                                                        | 0/200 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 model = trainer.train()
#
# File ~\anaconda3\Lib\site-packages\deepinv\training\trainer.py:795, in Trainer.train(self)
#     787 for i in (
#     788     progress_bar := tqdm(
#     789         range(batches),
#    (...)
#     792     )
#     793 ):
#     794     progress_bar.set_description(f"Train epoch {epoch + 1}/{self.epochs}")
# --> 795     self.step(
#     796         epoch, progress_bar, train=True, last_batch=(i == batches - 1)
#     797     )
#     799 self.loss_history.append(self.logs_total_loss_train.avg)
#     801 if self.scheduler:
#
# File ~\anaconda3\Lib\site-packages\deepinv\training\trainer.py:602, in Trainer.step(self, epoch, progress_bar, train, last_batch)
#     599 x, y, physics_cur = self.get_samples(self.current_iterators, g)
#     601 # Compute loss and perform backprop
# --> 602 x_net, logs = self.compute_loss(physics_cur, x, y, train=train, epoch=epoch)
#     604 # detach the network output for metrics and plotting
#     605 x_net = x_net.detach()
#
# File ~\anaconda3\Lib\site-packages\deepinv\training\trainer.py:464, in Trainer.compute_loss(self, physics, x, y, train, epoch)
#     461     self.optimizer.zero_grad()
#     463 # Evaluate reconstruction network
# --> 464 x_net = self.model_inference(y=y, physics=physics, x=x, train=train)
#     466 if train or self.display_losses_eval:
#     467     # Compute the losses
#     468     loss_total = 0
#
# File ~\anaconda3\Lib\site-packages\deepinv\training\trainer.py:440, in Trainer.model_inference(self, y, physics, x, train, **kwargs)
#     436     x_net, self.conv_metrics = self.model(
#     437         y, physics, x_gt=x, compute_metrics=True, **kwargs
#     438     )
#     439 else:
# --> 440     x_net = self.model(y, physics, **kwargs)
#     442 return x_net
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\anaconda3\Lib\site-packages\deepinv\unfolded\unfolded.py:103, in BaseUnfold.forward(self, y, physics, x_gt, compute_metrics, **kwargs)
#      92 def forward(self, y, physics, x_gt=None, compute_metrics=False, **kwargs):
#      93     r"""
#      94     Runs the fixed-point iteration algorithm. This is the same forward as in the parent BaseOptim class, but without the ``torch.no_grad()`` context manager.
#      95
#    (...)
#     101             Else, returns (torch.Tensor, dict) the output of the algorithm and the metrics.
#     102     """
# --> 103     X, metrics = self.fixed_point(
#     104         y, physics, x_gt=x_gt, compute_metrics=compute_metrics, **kwargs
#     105     )
#     106     x = self.get_output(X)
#     107     if compute_metrics:
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\anaconda3\Lib\site-packages\deepinv\optim\fixed_point.py:227, in FixedPoint.forward(self, compute_metrics, x_gt, *args, **kwargs)
#     205 def forward(self, *args, compute_metrics=False, x_gt=None, **kwargs):
#     206     r"""
#     207     Loops over the fixed-point iterator as (1) and returns the fixed point.
#     208
#    (...)
#     224                 otherwise.
#     225     """
#     226     X = (
# --> 227         self.init_iterate_fn(*args, F_fn=self.iterator.F_fn)
#     228         if self.init_iterate_fn
#     229         else None
#     230     )
#     231     metrics = (
#     232         self.init_metrics_fn(X, x_gt=x_gt)
#     233         if self.init_metrics_fn and compute_metrics
#     234         else None
#     235     )
#     236     self.check_iteration = True
#
# File ~\anaconda3\Lib\site-packages\deepinv\optim\optimizers.py:327, in BaseOptim.init_iterate_fn(self, y, physics, F_fn)
#     324     x_init, z_init = physics.A_adjoint(y), physics.A_adjoint(y)
#     325     init_X = {"est": (x_init, z_init)}
#     326 F = (
# --> 327     F_fn(
#     328         init_X["est"][0],
#     329         self.update_data_fidelity_fn(0),
#     330         self.update_prior_fn(0),
#     331         self.update_params_fn(0),
#     332         y,
#     333         physics,
#     334     )
#     335     if self.has_cost and F_fn is not None
#     336     else None
#     337 )
#     338 init_X["cost"] = F
#     339 return init_X
#
# File ~\anaconda3\Lib\site-packages\deepinv\optim\optimizers.py:525, in create_iterator.<locals>.F_fn(x, data_fidelity, prior, cur_params, y, physics)
#     524 def F_fn(x, data_fidelity, prior, cur_params, y, physics):
# --> 525     prior_value = prior(x, cur_params["g_param"], reduce=False)
#     526     if prior_value.dim() == 0:
#     527         reg_value = cur_params["lambda"] * prior_value
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\anaconda3\Lib\site-packages\deepinv\optim\potential.py:35, in Potential.forward(self, x, *args, **kwargs)
#      28 def forward(self, x, *args, **kwargs):
#      29     r"""
#      30     Computes the value of the potential :math:`h(x)`.
#      31
#      32     :param torch.Tensor x: Variable :math:`x` at which the potential is computed.
#      33     :return: (torch.tensor) prior :math:`h(x)`.
#      34     """
# ---> 35     return self.fn(x, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\deepinv\optim\potential.py:26, in Potential.fn(self, x, *args, **kwargs)
#      19 def fn(self, x, *args, **kwargs):
#      20     r"""
#      21     Computes the value of the potential :math:`h(x)`.
#      22
#      23     :param torch.Tensor x: Variable :math:`x` at which the potential is computed.
#      24     :return: (torch.tensor) prior :math:`h(x)`.
#      25     """
# ---> 26     return self._fn(x, *args, **kwargs)
#
# TypeError: 'generator' object is not callable

# %%
# Test model and plot results
# Out:
# Processing data of operator 1 out of 1
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.05s/it]
# Test PSNR: No learning rec.: 12.70+-0.00 dB | Model: 14.34+-0.00 dB.
# (14.339180946350098, 0.0, 12.69517993927002, 0.0)

# %%
trainer.test(test_dataloader)

test_sample, _ = next(iter(test_dataloader))
model.eval()
test_sample = test_sample.to(device)

# Get the measurements and the ground truth
y = physics(test_sample)
with torch.no_grad():  # it is important to disable gradient computation during testing.
    rec = model(y, physics=physics)

backprojected = physics.A_adjoint(y)

dinv.utils.plot(
    [backprojected, rec, test_sample],
    titles=["Linear", "Reconstruction", "Ground truth"],
    suptitle="Reconstruction results",
)
# Out:
# Test:   0%|                                                                                                                     | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 trainer.test(test_dataloader)
#       3 test_sample, _ = next(iter(test_dataloader))
#       4 model.eval()
#
# File ~\anaconda3\Lib\site-packages\deepinv\training\trainer.py:879, in Trainer.test(self, test_dataloader, save_path, compare_no_learning)
#     871 for i in (
#     872     progress_bar := tqdm(
#     873         range(batches),
#    (...)
#     876     )
#     877 ):
#     878     progress_bar.set_description(f"Test")
# --> 879     self.step(0, progress_bar, train=False, last_batch=(i == batches - 1))
#     881 self.wandb_vis = aux
#     883 if self.verbose:
#
# File ~\anaconda3\Lib\site-packages\deepinv\training\trainer.py:602, in Trainer.step(self, epoch, progress_bar, train, last_batch)
#     599 x, y, physics_cur = self.get_samples(self.current_iterators, g)
#     601 # Compute loss and perform backprop
# --> 602 x_net, logs = self.compute_loss(physics_cur, x, y, train=train, epoch=epoch)
#     604 # detach the network output for metrics and plotting
#     605 x_net = x_net.detach()
#
# File ~\anaconda3\Lib\site-packages\deepinv\training\trainer.py:464, in Trainer.compute_loss(self, physics, x, y, train, epoch)
#     461     self.optimizer.zero_grad()
#     463 # Evaluate reconstruction network
# --> 464 x_net = self.model_inference(y=y, physics=physics, x=x, train=train)
#     466 if train or self.display_losses_eval:
#     467     # Compute the losses
#     468     loss_total = 0
#
# File ~\anaconda3\Lib\site-packages\deepinv\training\trainer.py:440, in Trainer.model_inference(self, y, physics, x, train, **kwargs)
#     436     x_net, self.conv_metrics = self.model(
#     437         y, physics, x_gt=x, compute_metrics=True, **kwargs
#     438     )
#     439 else:
# --> 440     x_net = self.model(y, physics, **kwargs)
#     442 return x_net
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\anaconda3\Lib\site-packages\deepinv\unfolded\unfolded.py:103, in BaseUnfold.forward(self, y, physics, x_gt, compute_metrics, **kwargs)
#      92 def forward(self, y, physics, x_gt=None, compute_metrics=False, **kwargs):
#      93     r"""
#      94     Runs the fixed-point iteration algorithm. This is the same forward as in the parent BaseOptim class, but without the ``torch.no_grad()`` context manager.
#      95
#    (...)
#     101             Else, returns (torch.Tensor, dict) the output of the algorithm and the metrics.
#     102     """
# --> 103     X, metrics = self.fixed_point(
#     104         y, physics, x_gt=x_gt, compute_metrics=compute_metrics, **kwargs
#     105     )
#     106     x = self.get_output(X)
#     107     if compute_metrics:
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\anaconda3\Lib\site-packages\deepinv\optim\fixed_point.py:227, in FixedPoint.forward(self, compute_metrics, x_gt, *args, **kwargs)
#     205 def forward(self, *args, compute_metrics=False, x_gt=None, **kwargs):
#     206     r"""
#     207     Loops over the fixed-point iterator as (1) and returns the fixed point.
#     208
#    (...)
#     224                 otherwise.
#     225     """
#     226     X = (
# --> 227         self.init_iterate_fn(*args, F_fn=self.iterator.F_fn)
#     228         if self.init_iterate_fn
#     229         else None
#     230     )
#     231     metrics = (
#     232         self.init_metrics_fn(X, x_gt=x_gt)
#     233         if self.init_metrics_fn and compute_metrics
#     234         else None
#     235     )
#     236     self.check_iteration = True
#
# File ~\anaconda3\Lib\site-packages\deepinv\optim\optimizers.py:327, in BaseOptim.init_iterate_fn(self, y, physics, F_fn)
#     324     x_init, z_init = physics.A_adjoint(y), physics.A_adjoint(y)
#     325     init_X = {"est": (x_init, z_init)}
#     326 F = (
# --> 327     F_fn(
#     328         init_X["est"][0],
#     329         self.update_data_fidelity_fn(0),
#     330         self.update_prior_fn(0),
#     331         self.update_params_fn(0),
#     332         y,
#     333         physics,
#     334     )
#     335     if self.has_cost and F_fn is not None
#     336     else None
#     337 )
#     338 init_X["cost"] = F
#     339 return init_X
#
# File ~\anaconda3\Lib\site-packages\deepinv\optim\optimizers.py:525, in create_iterator.<locals>.F_fn(x, data_fidelity, prior, cur_params, y, physics)
#     524 def F_fn(x, data_fidelity, prior, cur_params, y, physics):
# --> 525     prior_value = prior(x, cur_params["g_param"], reduce=False)
#     526     if prior_value.dim() == 0:
#     527         reg_value = cur_params["lambda"] * prior_value
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\anaconda3\Lib\site-packages\deepinv\optim\potential.py:35, in Potential.forward(self, x, *args, **kwargs)
#      28 def forward(self, x, *args, **kwargs):
#      29     r"""
#      30     Computes the value of the potential :math:`h(x)`.
#      31
#      32     :param torch.Tensor x: Variable :math:`x` at which the potential is computed.
#      33     :return: (torch.tensor) prior :math:`h(x)`.
#      34     """
# ---> 35     return self.fn(x, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\deepinv\optim\potential.py:26, in Potential.fn(self, x, *args, **kwargs)
#      19 def fn(self, x, *args, **kwargs):
#      20     r"""
#      21     Computes the value of the potential :math:`h(x)`.
#      22
#      23     :param torch.Tensor x: Variable :math:`x` at which the potential is computed.
#      24     :return: (torch.tensor) prior :math:`h(x)`.
#      25     """
# ---> 26     return self._fn(x, *args, **kwargs)
#
# TypeError: 'generator' object is not callable

# %% [markdown]
# ### Test on SMLM image

# %%
gt = generate_ground_truth(28, 4, 4)
gt = torch.from_numpy(gt).to(torch.float)


blurred_image = ...
out = ...

plt.subplot(131)
plt.imshow(gt, cmap='gray')
plt.subplot(132)
plt.imshow(blurred_image[0, 0], cmap="gray")
plt.subplot(133)
plt.imshow(out.detach().numpy()[0, 0], cmap='gray')
plt.show()

# %% [markdown]
# ### Retraining on SMLM images
