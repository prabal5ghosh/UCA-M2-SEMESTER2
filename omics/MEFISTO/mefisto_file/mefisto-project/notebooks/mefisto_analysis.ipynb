# %% [markdown]
# # MEFISTO Analysis
#
# This notebook provides an interactive environment for analyzing the results of the MEFISTO model trained on the `evodevo.csv` dataset. It includes visualizations of the training process and insights into the learned latent factors.

# %%
import sys
import os

# Add the src directory to the Python path
sys.path.append(os.path.abspath('src'))

# %%
import sys
print(sys.path)
# Out:
# ['c:\\Users\\praba\\Documents\\GitHub\\UCA-M2-SEMESTER2\\omics\\MEFISTO\\mefisto_file\\mefisto-project\\notebooks', 'c:\\Users\\praba\\anaconda3\\python311.zip', 'c:\\Users\\praba\\anaconda3\\DLLs', 'c:\\Users\\praba\\anaconda3\\Lib', 'c:\\Users\\praba\\anaconda3', '', 'C:\\Users\\praba\\AppData\\Roaming\\Python\\Python311\\site-packages', 'c:\\Users\\praba\\anaconda3\\Lib\\site-packages', 'c:\\Users\\praba\\anaconda3\\Lib\\site-packages\\win32', 'c:\\Users\\praba\\anaconda3\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\praba\\anaconda3\\Lib\\site-packages\\Pythonwin', 'c:\\Users\\praba\\Documents\\GitHub\\UCA-M2-SEMESTER2\\omics\\MEFISTO\\mefisto_file\\mefisto-project\\notebooks\\src', 'c:\\Users\\praba\\Documents\\GitHub\\UCA-M2-SEMESTER2\\omics\\MEFISTO\\mefisto_file\\mefisto-project\\notebooks\\src']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\praba\Documents\GitHub\UCA-M2-SEMESTER2\omics\MEFISTO\mefisto_file\mefisto-project\notebooks

# %%
from src.data.data_loader import load_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from src.data.data_loader import load_data
#
# ModuleNotFoundError: No module named 'src'

# %%
from src.data.data_loader import load_data
from src.models.mefisto import MEFISTO
from src.training.trainer import Trainer
from src.visualization.plots import plot_loss_convergence, plot_latent_factors

# Load the dataset
data = load_data('data/evodevo.csv')

# %%
# Initialize the MEFISTO model
model = MEFISTO(input_dim=data.shape[1])

# Train the model
trainer = Trainer(model)
loss_history, recon_history, gp_history = trainer.train(data)

# Visualize the results
plt.figure(figsize=(12, 5))
plot_loss_convergence(loss_history, recon_history, gp_history)
Z_learned = model.get_latent_factors(data)
plot_latent_factors(Z_learned)

# %% [markdown]
# ## Conclusion
#
# In this notebook, we analyzed the performance of the MEFISTO model on the `evodevo.csv` dataset. The visualizations provided insights into the loss convergence and the learned latent factors over time.
