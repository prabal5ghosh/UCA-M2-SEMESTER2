# %%
import numpy as np
import pandas as pd
from mofapy2.run.entry_point import entry_point
import mofax
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Initialize the MEFISTO model
ent = entry_point()

datadir = "C:/Users/praba/Documents/GitHub/UCA-M2-SEMESTER2/omics/MEFISTO/13233860"

data = pd.read_csv(f"{datadir}/evodevo.csv", sep=",", index_col=0)
# Out:
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################

# %%
data
# Out:
#          group    view             sample                             feature  \
# 1        Human   Brain        10wpc_Human     ENSG00000000457_BrainBrainBrain
# 2        Human   Brain        10wpc_Human     ENSG00000001084_BrainBrainBrain
# 3        Human   Brain        10wpc_Human     ENSG00000001167_BrainBrainBrain
# 4        Human   Brain        10wpc_Human     ENSG00000001461_BrainBrainBrain
# 5        Human   Brain        10wpc_Human     ENSG00000001561_BrainBrainBrain
# ...        ...     ...                ...                                 ...
# 3193836  Human  Testis  youngMidAge_Human  ENSG00000271503_TestisTestisTestis
# 3193837  Human  Testis  youngMidAge_Human  ENSG00000271601_TestisTestisTestis
# 3193838  Human  Testis  youngMidAge_Human  ENSG00000272442_TestisTestisTestis
# 3193839  Human  Testis  youngMidAge_Human  ENSG00000272886_TestisTestisTestis
# 3193840  Human  Testis  youngMidAge_Human  ENSG00000273079_TestisTestisTestis
#
#              value  time
# 1         8.573918     7
# 2         8.875957     7
# 3        11.265237     7
# 4         7.374965     7
# 5         7.311018     7
# ...            ...   ...
# 3193836   1.178014    21
# 3193837   1.178014    21
# 3193838   4.476201    21
# 3193839   1.178014    21
# 3193840   8.311393    21
#
# [3193840 rows x 6 columns]

# %%
# Set data options and load into MEFISTO
ent.set_data_options()
ent.set_data_df(data)

# Define model options
ent.set_model_options(factors=5)
ent.set_train_options()
# Out:
# Loaded group='Human' view='Brain' with N=23 samples and D=7696 features...
# Loaded group='Human' view='Cerebellum' with N=23 samples and D=7696 features...
# Loaded group='Human' view='Heart' with N=23 samples and D=7696 features...
# Loaded group='Human' view='Liver' with N=23 samples and D=7696 features...
# Loaded group='Human' view='Testis' with N=23 samples and D=7696 features...
# Loaded group='Mouse' view='Brain' with N=14 samples and D=7696 features...
# Loaded group='Mouse' view='Cerebellum' with N=14 samples and D=7696 features...
# Loaded group='Mouse' view='Heart' with N=14 samples and D=7696 features...
# Loaded group='Mouse' view='Liver' with N=14 samples and D=7696 features...
# Loaded group='Mouse' view='Testis' with N=14 samples and D=7696 features...
# Loaded group='Opossum' view='Brain' with N=15 samples and D=7696 features...
# Loaded group='Opossum' view='Cerebellum' with N=15 samples and D=7696 features...
# Loaded group='Opossum' view='Heart' with N=15 samples and D=7696 features...
# Loaded group='Opossum' view='Liver' with N=15 samples and D=7696 features...
# Loaded group='Opossum' view='Testis' with N=15 samples and D=7696 features...
# Loaded group='Rabbit' view='Brain' with N=15 samples and D=7696 features...
# Loaded group='Rabbit' view='Cerebellum' with N=15 samples and D=7696 features...
# Loaded group='Rabbit' view='Heart' with N=15 samples and D=7696 features...
# Loaded group='Rabbit' view='Liver' with N=15 samples and D=7696 features...
# Loaded group='Rabbit' view='Testis' with N=15 samples and D=7696 features...
# Loaded group='Rat' view='Brain' with N=16 samples and D=7696 features...
# Loaded group='Rat' view='Cerebellum' with N=16 samples and D=7696 features...
# Loaded group='Rat' view='Heart' with N=16 samples and D=7696 features...
# Loaded group='Rat' view='Liver' with N=16 samples and D=7696 features...
# Loaded group='Rat' view='Testis' with N=16 samples and D=7696 features...
#
#
# WARNING: 'ard_factors' in model_options should be set to True if using multiple groups unless you are using MEFISTO
#
# Model options:
# - Automatic Relevance Determination prior on the factors: False
# - Automatic Relevance Determination prior on the weights: True
# - Spike-and-slab prior on the factors: False
# - Spike-and-slab prior on the weights: True
# Likelihoods:
# - View 0 (Brain): gaussian
# - View 1 (Cerebellum): gaussian
# - View 2 (Heart): gaussian
# - View 3 (Liver): gaussian
# - View 4 (Testis): gaussian

# %%
# Set covariates (e.g., time) for temporal analysis
times = [
    data[['sample', 'time', 'group']]
    .drop_duplicates()
    .set_index('sample')
    .loc[np.concatenate(ent.data_opts['samples_names'])]
    .query('group == @g').time.values.reshape(-1, 1) 
    for g in ent.data_opts['groups_names']
]

idx = ent.data_opts['groups_names'].index("Mouse")
ent.set_covariates(times, covariates_names="time")
ent.set_smooth_options(warping=True, warping_ref=idx, model_groups=True)
# Out:
# Loaded 1 covariate(s) for each sample...
#
#
# ##
# ## Warping set to True: aligning the covariates across groups
# ##

# %%
# Build and run the model
ent.build()
ent.run()

# Save trained model
ent.save("evodevo_model_1.hdf5")
# Out:
# ######################################
# ## Training the model with seed 179526 ##
# ######################################
#
#
# ELBO before training: -15640469.48
#
# Iteration 1: time=0.65, ELBO=-3990165.32, deltaELBO=11650304.153 (74.48819979%), Factors=5
# Iteration 2: time=0.67, ELBO=-3374830.97, deltaELBO=615334.355 (3.93424479%), Factors=5
# Iteration 3: time=0.64, ELBO=-3251851.18, deltaELBO=122979.793 (0.78629221%), Factors=5
# Iteration 4: time=0.65, ELBO=-3199105.80, deltaELBO=52745.379 (0.33723655%), Factors=5
# Iteration 5: time=0.67, ELBO=-3165665.00, deltaELBO=33440.797 (0.21380942%), Factors=5
# Iteration 6: time=0.64, ELBO=-3141328.17, deltaELBO=24336.830 (0.15560166%), Factors=5
# Iteration 7: time=0.85, ELBO=-3123042.87, deltaELBO=18285.304 (0.11691020%), Factors=5
# Iteration 8: time=0.73, ELBO=-3109604.60, deltaELBO=13438.263 (0.08591982%), Factors=5
# Iteration 9: time=0.73, ELBO=-3100183.88, deltaELBO=9420.729 (0.06023303%), Factors=5
# Iteration 10: time=0.80, ELBO=-3093869.90, deltaELBO=6313.971 (0.04036945%), Factors=5
# Iteration 11: time=0.82, ELBO=-3089657.90, deltaELBO=4212.000 (0.02693014%), Factors=5
# Iteration 12: time=1.05, ELBO=-3086802.78, deltaELBO=2855.124 (0.01825472%), Factors=5
# Iteration 13: time=1.12, ELBO=-3084804.18, deltaELBO=1998.598 (0.01277838%), Factors=5
# Iteration 14: time=0.61, ELBO=-3083340.13, deltaELBO=1464.055 (0.00936068%), Factors=5
# Iteration 15: time=0.71, ELBO=-3082219.81, deltaELBO=1120.319 (0.00716295%), Factors=5
# Iteration 16: time=0.59, ELBO=-3081405.99, deltaELBO=813.821 (0.00520330%), Factors=5
# Iteration 17: time=0.64, ELBO=-3080804.94, deltaELBO=601.047 (0.00384289%), Factors=5
# Iteration 18: time=0.75, ELBO=-3080333.91, deltaELBO=471.028 (0.00301160%), Factors=5
# Iteration 19: time=0.67, ELBO=-3079965.44, deltaELBO=368.476 (0.00235592%), Factors=5
# Importing the dtw module. When using in academic works please cite:
#   T. Giorgino. Computing and Visualizing Dynamic Time Warping Alignments in R: The dtw Package.
#   J. Stat. Soft., doi:10.18637/jss.v031.i07.
#
# Covariates were aligned between groups.
# Optimising sigma node...
# Iteration 20: time=89.87, ELBO=-3079050.35, deltaELBO=915.082 (0.00585073%), Factors=5
# Iteration 21: time=0.67, ELBO=-3078799.00, deltaELBO=251.353 (0.00160707%), Factors=5
# Iteration 22: time=0.64, ELBO=-3078589.13, deltaELBO=209.874 (0.00134186%), Factors=5
# Iteration 23: time=0.61, ELBO=-3078420.52, deltaELBO=168.606 (0.00107801%), Factors=5
# Iteration 24: time=0.56, ELBO=-3078281.97, deltaELBO=138.555 (0.00088587%), Factors=5
# Iteration 25: time=0.59, ELBO=-3078154.91, deltaELBO=127.053 (0.00081233%), Factors=5
# Iteration 26: time=0.60, ELBO=-3078034.62, deltaELBO=120.293 (0.00076912%), Factors=5
# Iteration 27: time=0.62, ELBO=-3077925.07, deltaELBO=109.549 (0.00070042%), Factors=5
# Iteration 28: time=0.56, ELBO=-3077826.94, deltaELBO=98.129 (0.00062740%), Factors=5
# Iteration 29: time=0.59, ELBO=-3077738.32, deltaELBO=88.626 (0.00056664%), Factors=5
# Optimising sigma node...
# Iteration 30: time=51.04, ELBO=-3077650.88, deltaELBO=87.437 (0.00055904%), Factors=5
# Iteration 31: time=0.62, ELBO=-3077549.95, deltaELBO=100.935 (0.00064535%), Factors=5
# Iteration 32: time=0.60, ELBO=-3077465.15, deltaELBO=84.793 (0.00054214%), Factors=5
# Iteration 33: time=0.60, ELBO=-3077392.95, deltaELBO=72.204 (0.00046165%), Factors=5
# Iteration 34: time=0.63, ELBO=-3077328.27, deltaELBO=64.677 (0.00041352%), Factors=5
#
# Converged!
#
#
#
# #######################
# ## Training finished ##
# #######################
#
#
# Saving model in evodevo_model_1.hdf5...

# %%
m = mofax.mofa_model(r"C:\Users\praba\Documents\GitHub\UCA-M2-SEMESTER2\omics\MEFISTO\evodevo_model_1.hdf5")

# %%
# Plot variance explained
mofax.plot_r2(m, cmap="Blues")

# %%
# Visualize factor space
mofax.plot_factors_scatter(m, x=0, y=1, color=["group", "time", "time_transformed"])
# Out:
# <Axes: title={'center': 'time_transformed'}, xlabel='Factor1', ylabel='Factor2'>

# %%
# Plot latent factors over developmental time
mofax.plot_factors_scatter(m, x="time_transformed", y=range(m.nfactors), ncols=5, size=70)
# Out:
# <Axes: title={'center': 'Factor5'}, xlabel='time_transformed', ylabel='Factor5'>

# %%
# Plot smoothness of factors
mofax.plot_smoothness(m)
# Out:
# <Axes: xlabel='Smoothness', ylabel='Factor'>

# %%
# Plot sharedness across species
to_plot = ["Factor1", "Factor2", "Factor3"]
mofax.plot_group_kernel(m, factors=to_plot)

plt.show()

# %%
mofax.plot_group_kernel(m, ncols=5);
